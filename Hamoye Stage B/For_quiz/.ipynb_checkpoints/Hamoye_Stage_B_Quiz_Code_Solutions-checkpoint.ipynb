# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
energy_data = pd.read_csv('energydata_complete.csv')

# %%
energy_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_data.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# ## Question 12 solutions

# %%
lin_mod= LinearRegression()

# %%
first_x = energy_data[['T2']]
first_y = energy_data[['T6']]

# %%
lin_mod.fit(first_x, first_y)
# Out:
# LinearRegression()

# %%
prd_lin_mod = lin_mod.predict(first_x)

# %%
# question 12
round((r2_score(first_y, prd_lin_mod)), 2)
# Out:
# 0.64

# %% [markdown]
# ## Question 13 - 17 solutions

# %%
X= energy_data.drop(['date', 'lights'], axis= 1)

# %%
normalized_data = MinMaxScaler()

# %%
X = pd.DataFrame(normalized_data.fit_transform(X.values), columns=X.columns, index=X.index)

# %%
X
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
new_x = X.drop('Appliances', axis= 1)
new_y = X[['Appliances']]

# %%
new_x
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(new_x, new_y, test_size=0.30, random_state=42)

# %%
new_lin_mod = LinearRegression()

# %%
new_lin_mod.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
new_pred = new_lin_mod.predict(X_test)

# %%
# question 13
round(mean_absolute_error(y_test, new_pred), 2)
# Out:
# 0.05

# %%
# question 14
round(mean_squared_error(y_test, new_pred), 2)
# Out:
# 0.01

# %%
# question 15
round(np.sqrt(mean_squared_error(y_test, new_pred)), 3)
# Out:
# 0.088

# %%
# question 16
round(r2_score(y_test, new_pred), 2)
# Out:
# 0.15

# %%
# question 17
coeff = pd.Series(new_lin_mod.coef_[0], index = new_x.columns)

# %%
coeff[coeff.values == np.min(new_lin_mod.coef_)]
# Out:
# RH_2   -0.456698
# dtype: float64

# %%
coeff[coeff.values == np.max(new_lin_mod.coef_)]
# Out:
# RH_1    0.553547
# dtype: float64

# %% [markdown]
# ## Question 18 solutions

# %%
ridge = Ridge(alpha= 0.4)

# %%
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
ridge_pred = ridge.predict(X_test)

# %%
# question 18
round(np.sqrt(mean_squared_error(y_test, ridge_pred)), 3)
# Out:
# 0.088

# %% [markdown]
# ## Question 19 - 20 solutions

# %%
lasso = Lasso(alpha= 0.001)

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
# question 19
sum(lasso.coef_ > 0) + sum(lasso.coef_ < 0)
# Out:
# 4

# %%
lasso_pred = lasso.predict(X_test)

# %%
# question 20
round(np.sqrt(mean_squared_error(y_test, lasso_pred)), 3)
# Out:
# 0.094
